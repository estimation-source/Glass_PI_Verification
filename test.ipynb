# %%
import src.excel_reader as er

print(dir(er))
# Out:
# ['Any', 'Dict', 'GlassRecord', 'HEADER_REMOVE_PATTERN', 'HEADER_SCAN_LIMIT', 'HeaderBlock', 'HeaderInfo', 'KEYWORDS', 'List', 'Optional', 'Tuple', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'annotations', 'asdict', 'build_header_blocks', 'build_record_buffers', 'build_window_code', 'collect_glass', 'collect_numeric_from_buffer', 'contains_keywords', 'dataclass', 'detect_column', 'detect_header_columns', 'field', 'find_business_sheets', 'find_header_blocks', 'io', 'is_business_header', 'is_record_start', 'load_excel_with_calculated_values', 'math', 'normalize_header', 'normalize_header_row', 'openpyxl', 'parse_business_sheet', 'parse_header_block', 'pd', 'process_uploaded_files', 're', 'safe_numeric', 'score_business_sheet', 'standardize_glass_spec']

# %%
from src.pdf_reader import read_pdf
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from src.pdf_reader import read_pdf
#
# File ~\Glass_PI_Verification\src\pdf_reader.py:17
#      14 import pandas as pd
#      16 from src.logger import info, warning, error
# ---> 17 from src.exceptions import PDFReadError
#      20 # ==========================================================
#      21 # LOGGER
#      22 # ==========================================================
#      24 logger = logging.getLogger(__name__)
#
# ImportError: cannot import name 'PDFReadError' from 'src.exceptions' (C:\Users\ADMIN\Glass_PI_Verification\src\exceptions.py)

# %%
print(pdf_df[["WindowCode", "Remark", "Width", "Height", "Qty"]].head(20))
